# %% [markdown]
# # LAB 01 Importing and Exporting Datasets

# %% [markdown]
# STT: 11
#
# Họ và tên: Nguyễn Mạnh Đức
#
# Lớp: DS105.N11.2
#
# Buổi 01 - Bài 01

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Câu 1

# %%
# Đọc dữ liệu, lưu dữ liệu vào df
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data')

# %%
# In ra 10 sample đầu tiên 
df.head(10)
# Out:
#    3    ?  alfa-romero  gas    std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas    std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas    std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas    std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas    std   two        sedan  fwd  front   99.8  ...
# 5  1  158         audi  gas    std  four        sedan  fwd  front  105.8  ...
# 6  1    ?         audi  gas    std  four        wagon  fwd  front  105.8  ...
# 7  1  158         audi  gas  turbo  four        sedan  fwd  front  105.8  ...
# 8  0    ?         audi  gas  turbo   two    hatchback  4wd  front   99.5  ...
# 9  2  192          bmw  gas    std   two        sedan  rwd  front  101.2  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# ...

# %%
# In ra 5 sample bất kỳ 
df.sample(5)
# Out:
#      3    ? alfa-romero     gas    std   two convertible  rwd  front  88.60  \
# 202 -1   95       volvo  diesel  turbo  four       sedan  rwd  front  109.1
# 35   0   78       honda     gas    std  four       wagon  fwd  front   96.5
# 75   2  161  mitsubishi     gas    std   two   hatchback  fwd  front   93.7
# 50   1  104       mazda     gas    std   two   hatchback  fwd  front   93.1
# 168  2  134      toyota     gas    std   two   hatchback  rwd  front   98.4
#
#      ...  130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 202  ...  145   idi  3.01  3.40  23.0  106  4800  26  27  22470
# 35   ...   92  1bbl  2.92  3.41   9.2   76  6000  30  34   7295
# 75   ...   92  2bbl  2.97  3.23   9.4   68  5500  37  41   5389
# 50   ...   91  2bbl  3.03  3.15   9.0   68  5000  31  38   6095
# 168  ...  146  mpfi  3.62  3.50   9.3  116  4800  24  30   9989
#
# [5 rows x 26 columns]

# %% [markdown]
# # Câu 2

# %%
# Tạo header cho các cột
df.columns = ["symboling", 
"normalized-losses", "make", "fuel-type", "aspiration", "num-of-doors", 
"body-style", "drive-wheels", "engine-location", "wheel-base", "length", 
"width", "height", "curb-weight", "engine-type", "num-of-cylinders", "enginesize", "fuel-system", "bore", "stroke", "compression-ratio", "horsepower", 
"peak-rpm", "city-mpg", "highway-mpg", "price"]

df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# Xuất 6 sample đầu tiên 
df.head(6)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  enginesize  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# ...

# %%
# Xuất 7 sample cuối cùng
df.tail(7)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 197         -2               103  volvo       gas      turbo         four
# 198         -1                74  volvo       gas      turbo         four
# 199         -1                95  volvo       gas        std         four
# 200         -1                95  volvo       gas      turbo         four
# 201         -1                95  volvo       gas        std         four
# 202         -1                95  volvo    diesel      turbo         four
# 203         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  enginesize  \
# 197      sedan          rwd           front       104.3  ...          130
# 198      wagon          rwd           front       104.3  ...          130
# 199      sedan          rwd           front       109.1  ...          141
# 200      sedan          rwd           front       109.1  ...          141
# ...

# %%
# In ra 8 samples ngẫu nhiên
df.sample(8)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 145          0                89      subaru       gas        std
# 13           1                 ?         bmw       gas        std
# 188          3                 ?  volkswagen       gas        std
# 49           1               104       mazda       gas        std
# 47           0                 ?      jaguar       gas        std
# 61           0               115       mazda       gas        std
# 200         -1                95       volvo       gas      turbo
# 199         -1                95       volvo       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 145         four        wagon          fwd           front        97.0  ...
# 13          four        sedan          rwd           front       103.5  ...
# 188          two  convertible          fwd           front        94.5  ...
# ...

# %% [markdown]
# # Câu 3

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'enginesize', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Câu 4

# %%
df.loc[5]
# Out:
# symboling                1
# normalized-losses      158
# make                  audi
# fuel-type              gas
# aspiration             std
# num-of-doors          four
# body-style           sedan
# drive-wheels           fwd
# engine-location      front
# wheel-base           105.8
# length               192.7
# width                 71.4
# height                55.7
# curb-weight           2844
# engine-type            ohc
# num-of-cylinders      five
# enginesize            136
# fuel-system           mpfi
# bore                  3.19
# stroke                3.40
# compression-ratio      8.5
# horsepower             110
# peak-rpm              5500
# city-mpg                19
# highway-mpg             25
# price                17710
# Name: 5, dtype: object

# %%
df.iloc[3:5, 5:8]
# Out:
#   num-of-doors body-style drive-wheels
# 3         four      sedan          4wd
# 4          two      sedan          fwd

# %% [markdown]
# # Câu 5

# %%
# Chuyển df sang mảng 2 chiều, lưu vào df_array
df_array = df.values

# %% [markdown]
# # Câu 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  204 non-null    object
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %% [markdown]
# Nhận xét:
#
# 1 số feature không đúng với kiểu dữ liệu mong muốn
#
# Cột price: đang là object cần chuyển thành float
#
# Cột peak-rpm: đang là object cần chuyển thành float
#
# Cột stroke: đang là object cần chuyển thành float
#
# Cột bore: đang là object cần chuyển thành float

# %% [markdown]
# # Câu 7

# %%
df[['length','compression-ratio','price']].describe()
# Out:
#            length  compression-ratio
# count  204.000000         204.000000
# mean   174.075000          10.148137
# std     12.362123           3.981000
# min    141.100000           7.000000
# 25%    166.300000           8.575000
# 50%    173.200000           9.000000
# 75%    183.200000           9.400000
# max    208.100000          23.000000

# %% [markdown]
# Nhận xét:
#
# Kiểu dữ liệu của "length" và "compression-ratio" đang là float nên khi dùng hàm describe() thì có hiển thị
#
# Kiểu dữ liệu của "price" đang là object nên không xuất hiện trong bảng

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Câu 8

# %%
df[(df["price"]=='?')|(df["price"]=='.')|(df["price"]=='')]
# Out:
#      symboling normalized-losses     make fuel-type aspiration num-of-doors  \
# 8            0                 ?     audi       gas      turbo          two
# 43           1                 ?    isuzu       gas        std          two
# 44           0                 ?    isuzu       gas        std         four
# 128          1                 ?  porsche       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  enginesize  \
# 8    hatchback          4wd           front        99.5  ...          131
# 43       sedan          fwd           front        94.5  ...           90
# 44       sedan          fwd           front        94.5  ...           90
# 128  hatchback          rwd           front        98.4  ...          203
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 8           mpfi  3.13    3.40               7.0        160      5500
# 43          2bbl  3.03    3.11               9.6         70      5400
# ...

# %% [markdown]
# # Câu 9

# %%
df[(df["normalized-losses"]=='?')|(df["normalized-losses"]=='.')|(df["normalized-losses"]=='')]
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 0            3                 ?    alfa-romero       gas        std
# 1            1                 ?    alfa-romero       gas        std
# 4            2                 ?           audi       gas        std
# 6            1                 ?           audi       gas        std
# 8            0                 ?           audi       gas      turbo
# 13           1                 ?            bmw       gas        std
# 14           0                 ?            bmw       gas        std
# 15           0                 ?            bmw       gas        std
# 16           0                 ?            bmw       gas        std
# 42           0                 ?          isuzu       gas        std
# 43           1                 ?          isuzu       gas        std
# 44           0                 ?          isuzu       gas        std
# 45           2                 ?          isuzu       gas        std
# ...

# %% [markdown]
# # Câu 10

# %%
df[df.columns[::-1]]
# Out:
#      price  highway-mpg  city-mpg peak-rpm horsepower  compression-ratio  \
# 0    16500           27        21     5000        111                9.0
# 1    16500           26        19     5000        154                9.0
# 2    13950           30        24     5500        102               10.0
# 3    17450           22        18     5500        115                8.0
# 4    15250           25        19     5500        110                8.5
# ..     ...          ...       ...      ...        ...                ...
# 199  16845           28        23     5400        114                9.5
# 200  19045           25        19     5300        160                8.7
# 201  21485           23        18     5500        134                8.8
# 202  22470           27        26     4800        106               23.0
# 203  22625           25        19     5400        114                9.5
#
#     stroke  bore fuel-system  enginesize  ... wheel-base engine-location  \
# ...

# %% [markdown]
# # Câu 11

# %%
df.append({}, ignore_index=True)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0          3.0                 ?  alfa-romero       gas        std
# 1          1.0                 ?  alfa-romero       gas        std
# 2          2.0               164         audi       gas        std
# 3          2.0               164         audi       gas        std
# 4          2.0                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200       -1.0                95        volvo       gas      turbo
# 201       -1.0                95        volvo       gas        std
# 202       -1.0                95        volvo    diesel      turbo
# 203       -1.0                95        volvo       gas      turbo
# 204        NaN               NaN          NaN       NaN        NaN
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # Câu 12

# %%
df.to_csv("/content/drive/MyDrive/Lab01.csv")

# %%
df.to_json("/content/drive/MyDrive/Lab01.json")

# %%
# !pip install xlsxwriter
df.to_excel("/content/drive/MyDrive/Lab01.xlsx")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 149 kB 2.1 MB/s
# ...

# %%
df.to_hdf("/content/drive/MyDrive/Lab01.h5", key='df')
